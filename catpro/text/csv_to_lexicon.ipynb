# %%
'''
Authors: Daniel M. Low
License: See license in github repository
'''

import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime


pd.set_option("display.max_columns", None)
# pd.options.display.width = 0


on_colab = False

if on_colab:
  from google.colab import drive
  project_name = 'project_name'
  drive.mount('/content/drive')
  input_dir = f'/content/drive/MyDrive/datum/{project_name}/data/input/'
  output_dir = f'/content/drive/MyDrive/datum/{project_name}/data/output/'
else:
  input_dir = './data/lexicons/'
  output_dir = './data/lexicons/'

os.makedirs(output_dir, exist_ok=True)

df = pd.read_excel(input_dir + 'suicide_questionnaire_item_lexicons_20220913.xlsx', sheet_name = 0)
references = pd.read_excel(input_dir + 'suicide_questionnaire_item_lexicons_20220913.xlsx', sheet_name = 1)
references
# Out:
#     Risk factor number                                        Risk factor  \
# 0                    1                                       hopelessness
# 1                    1                                       hopelessness
# 2                    2                                 sleep disturbances
# 3                    2                                 sleep disturbances
# 4                    3                                          agitation
# 5                    4                                     burdensomeness
# 6                    5                                         loneliness
# 7                    6                                       humilliation
# 8                    7                                 low social support
# 9                    8                                          anhedonia
# 10                   8                                          anhedonia
# 11                   8                                          anhedonia
# 12                   9                                         aggression
# 13                   9                                         aggression
# 14                  10  entrapment/panic-dissociation/severe emotional...
# 15                  11                              no purpose for living
# 16                  12             planning suicide/talking about suicide
# 17                  13                                            fatigue
# 18                  14                                  social withdrawal
# 19                  15                              emotion dysregulation
# 20                  16              borderline personality disorder (BPD)
# 21                  16  borderline/histrionic/antisocial personality d...
# 22                  17                                       self-disgust
# 23                  18                                            burnout
# 24                  19                                             stigma
# 25                  20                                        impulsivity
# 26                  21                                            anxiety
# 27                  21                                            anxiety
# 28                  22  depressive symptoms: depressive mood, blame/gu...
# 29                  23                                       chronic pain
# 30                  24                              barriers to treatment
# 31                  24                              barriers to treatment
#
#                                                 Scale  \
# 0                       Beck's hopelessness inventory
# 1                                    Adult Hope Scale
# 2                    Sleep disorders screening survey
# 3                Sleep disorders symptom chechlist 25
# 4                                 H2A agitation scale
# 5                         Self perceived burden scale
# 6                            De Jong Loneliness scale
# 7                               Humiliation Inventory
# 8                           MOS social support survey
# 9                      Snaith-Hamilton Pleasure Scale
# 10   The Fawcett-Clark Pleasure Capacity Scale (FCPS)
# 11          Dimensional Anhedonia Rating Scale (DARS)
# 12                 Buss Perry Aggression Questionaire
# 13                 The Brief Irritability Test (BITe)
# 14                     Suicide Crisis Inventory (SCI)
# 15                              Purpose in Life Scale
# 16             Columbia Suicide Severity Rating Scale
# 17                     Fatigue Assessment Scale (FAS)
# 18                    Research Survey of Youth's Life
# 19    Difficulties in Emotion Regulation Scale (DERS)
# 20                   Borderline Personality Checklist
# 21                                            SCID II
# 22  Questionnaire for the  Assessment of Self-Disgust
# 23                       Burnout Assesment Tool (BAT)
# 24                                   The Stigma Scale
# 25                         Barrat Impulsiveness Scale
# 26           State-Trait Anxiety Inventory for Adults
# 27                       Beck Anxiety Inventory (BAI)
# 28                    Beck Depression Inventory (BDI)
# 29     Bodily and Emotional Perception of Pain (BEEP)
# 30  The Barriers to Mental Health Services Scale -...
# 31       The Barriers to Mental Health Services Scale
#
#                                                  Link  Reference
# 0   https://drive.google.com/file/d/1zy56xnZZmHbLg...        NaN
# 1   https://drive.google.com/file/d/1HiiPtYR1XjXc8...        NaN
# 2   https://healthysleep.med.harvard.edu/healthy/g...        NaN
# 3   https://drive.google.com/file/d/186pKEztGbVBoX...        NaN
# 4   https://drive.google.com/file/d/16p40qu6rnYkDH...        NaN
# 5   https://drive.google.com/file/d/1SsRBsZiZt6K4P...        NaN
# 6   https://drive.google.com/file/d/1btfshuN9YZRut...        NaN
# 7   https://drive.google.com/file/d/1EO-Jk1hPqXp2w...        NaN
# 8                                                 NaN        NaN
# 9   https://drive.google.com/file/d/1ErsQdxmyXKCKw...        NaN
# 10  https://drive.google.com/file/d/1AafMmeKKTRj_a...        NaN
# 11  https://drive.google.com/file/d/1g3N3oGh17ATvw...        NaN
# 12  https://psychology-tools.com/test/buss-perry-a...        NaN
# 13  https://drive.google.com/file/d/1hS6ny3vYmiLXu...        NaN
# 14  https://drive.google.com/file/d/1-B9RKi03g9z5x...        NaN
# 15  https://drive.google.com/file/d/1h83z2u8r7vkfg...        NaN
# 16  https://drive.google.com/file/d/19GXJ5PFPnfql9...        NaN
# 17  https://drive.google.com/file/d/1IeLHA_g327YHg...        NaN
# 18               https://apjjf.org/2017/05/Tajan.html        NaN
# 19  https://drive.google.com/file/d/1H6w_YzOg8r5ui...        NaN
# 20  https://drive.google.com/file/d/1E8ewXgzX5sPAX...        NaN
# 21  https://drive.google.com/file/d/1DxbxygUn8fngF...        NaN
# 22  https://docs.google.com/document/d/1ERkBfEWMcM...        NaN
# 23  https://drive.google.com/file/d/1IeWAt1ZWOd_7g...        NaN
# 24  https://drive.google.com/file/d/1oiYMVNvMHIDpD...        NaN
# 25  https://drive.google.com/file/d/1dc4P8yt5UlLuE...        NaN
# 26  https://drive.google.com/file/d/1HEK9wY1EIB-HU...        NaN
# 27  https://drive.google.com/file/d/1-0fkS0SXInr2T...        NaN
# 28  https://drive.google.com/file/d/1HEK9wY1EIB-HU...        NaN
# 29  https://drive.google.com/file/d/17IclUYWreduL0...        NaN
# 30  https://drive.google.com/file/d/1OjapS1SB135wj...        NaN
# 31  https://drive.google.com/file/d/17vf3m8XBYPghR...        NaN
